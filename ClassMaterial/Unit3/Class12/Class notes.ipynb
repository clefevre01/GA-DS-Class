# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
df = pd.read_csv('/Users/cameronlefevre/Test-Repo/ClassMaterial/Unit3/data/housing.csv')

# %%
tree = DecisionTreeRegressor()

# %%
X = df.drop('PRICE', axis=1)
y = df['PRICE']

# %%
guess = y.mean()

# %%
guess
# Out:
# 22.532806324110698

# %%
y - guess
# Out:
# 0       1.467194
# 1      -0.932806
# 2      12.167194
# 3      10.867194
# 4      13.667194
#          ...
# 501    -0.132806
# 502    -1.932806
# 503     1.367194
# 504    -0.532806
# 505   -10.632806
# Name: PRICE, Length: 506, dtype: float64

# %%
gradient = y - guess

# %%
tree.fit(X, gradient)
# Out:
# DecisionTreeRegressor()

# %%
tree.predict(X)
# Out:
# array([  1.46719368,  -0.93280632,  12.16719368,  10.86719368,
#         13.66719368,   6.16719368,   0.36719368,   4.56719368,
#         -6.03280632,  -3.63280632,  -7.53280632,  -3.63280632,
#         -0.83280632,  -2.13280632,  -4.33280632,  -2.63280632,
#          0.56719368,  -5.03280632,  -2.33280632,  -4.33280632,
#         -8.93280632,  -2.93280632,  -7.33280632,  -8.03280632,
#         -6.93280632,  -8.63280632,  -5.93280632,  -7.73280632,
#         -4.13280632,  -1.53280632,  -9.83280632,  -8.03280632,
#         -9.33280632,  -9.43280632,  -9.03280632,  -3.63280632,
#         -2.53280632,  -1.53280632,   2.16719368,   8.26719368,
#         12.36719368,   4.06719368,   2.76719368,   2.16719368,
#         -1.33280632,  -3.23280632,  -2.53280632,  -5.93280632,
#         -8.13280632,  -3.13280632,  -2.83280632,  -2.03280632,
#          2.46719368,   0.86719368,  -3.63280632,  12.86719368,
#          2.16719368,   9.06719368,   0.76719368,  -2.93280632,
# ...

# %%
df = pd.read_csv('/Users/cameronlefevre/Test-Repo/ClassMaterial/Unit3/data/restaurants.csv', parse_dates=['visit_date'])

# %%
df.head()
# Out:
#                      id visit_date  visitors calendar_date day_of_week  \
# 0  air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1  air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2  air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3  air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4  air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
#
#    holiday       genre                          area   latitude   longitude  \
# 0        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 1        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 3        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 4        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
#
#    reserve_visitors
# 0               NaN
# 1               NaN
# ...

# %%
df.reserve_visitors.value_counts().sort_index()
# Out:
# 1.0      1975
# 2.0     13587
# 3.0      5376
# 4.0      8042
# 5.0      3581
# 6.0      4627
# 7.0      6713
# 8.0      5639
# 9.0      3738
# 10.0     6703
# 11.0     2439
# 12.0     3677
# 13.0      744
# 14.0     1318
# 15.0     2259
# 16.0      704
# 17.0     1459
# 18.0     1047
# 20.0      722
# 21.0     2591
# 22.0      696
# 23.0     3564
# 24.0      613
# 25.0     3476
# 27.0      736
# 28.0      706
# 30.0     1297
# 31.0      738
# 32.0     1182
# 33.0      771
# 35.0     1358
# 36.0     2033
# 37.0      774
# 40.0      731
# 41.0      772
# 42.0      608
# 43.0     1372
# 44.0     1246
# 46.0     1393
# 47.0      771
# 48.0      603
# 51.0      659
# 54.0      767
# 58.0      574
# 59.0      672
# 60.0     1411
# 76.0      767
# 83.0      575
# 96.0      588
# Name: reserve_visitors, dtype: int64

# %%
def denote_null_values(df):
    empty_cols_query = df.isnull().sum() > 0
    empty_df_cols = df.loc[:, empty_cols_query].columns.tolist()
    for col in empty_df_cols:
        col_name = f"{col}_missing"
        df[col_name] = pd.isnull(df[col])
    return df

# %%
denote_null_values(df)
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 252103  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df = denote_null_values(df)
# and fill in the missing ones
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# id                          0
# visit_date                  0
# visitors                    0
# calendar_date               0
# day_of_week                 0
# holiday                     0
# genre                       0
# area                        0
# latitude                    0
# longitude                   0
# reserve_visitors            0
# reserve_visitors_missing    0
# dtype: int64

# %%
filled = df[~df['reserve_visitors'].isnull()]
missing = df[df['reserve_visitors'].isnull()]

# %%
filled
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 252103  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
X = filled[['visitors', 'holiday', 'latitude', 'longitude']]
y = filled['reserve_visitors']

# %%
gmb = GradientBoostingRegressor()

# %%
gbm.fit(X, y)
# Out:
# GradientBoostingRegressor()

# %%
gbm.predict(missing[['visitors', 'holiday', 'latitude', 'longitude']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-01b204b4bddb> in <module>
# ----> 1 gbm.predict(missing[['visitors', 'holiday', 'latitude', 'longitude']])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py in predict(self, X)
#    1607             The predicted values.
#    1608         """
# -> 1609         X = check_array(X, dtype=DTYPE, order="C", accept_sparse='csr')
#    1610         # In regression we can directly return the raw value from the trees.
#    1611         return self._raw_predict(X).ravel()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ...

# %%
import category_encoders as ce

# %%
# initialize
encoder = ce.OrdinalEncoder()
# and use the fit_transform() method
encoder.fit_transform(df)
# Out:
#          id visit_date  visitors  calendar_date  day_of_week  holiday  genre  \
# 0         1 2016-01-13        25              1            1        0      1
# 1         1 2016-01-14        32              2            2        0      1
# 2         1 2016-01-15        29              3            3        0      1
# 3         1 2016-01-16        22              4            4        0      1
# 4         1 2016-01-18         6              5            5        0      1
# ...     ...        ...       ...            ...          ...      ...    ...
# 252103  829 2017-04-21        49            390            3        0      4
# 252104  829 2017-04-22        60            391            4        0      4
# 252105  829 2017-03-26        69            444            7        0      4
# 252106  829 2017-03-20        31            467            5        1      4
# 252107  829 2017-04-09        26            468            7        0      4
#
# ...

# %%
df
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 252103  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
encoder.mapping
# Out:
# [{'col': 'id',
#   'mapping': air_ba937bf13d40fb24      1
#   air_25e9888d30b386df      2
#   air_fd6aac1043520e83      3
#   air_64d4491ad8cdb1c6      4
#   air_ee3a01f0c71a769f      5
#                          ...
#   air_cf5ab75a0afb8af9    826
#   air_1c0b150f9e696a5f    827
#   air_900d755ebd2f7bbd    828
#   air_a17f0778617c76e2    829
#   NaN                      -2
#   Length: 830, dtype: int64,
#   'data_type': dtype('O')},
#  {'col': 'calendar_date',
#   'mapping': 2016-01-13      1
#   2016-01-14      2
#   2016-01-15      3
#   2016-01-16      4
#   2016-01-18      5
#                ...
#   2016-01-01    475
#   2016-01-03    476
#   2017-01-02    477
#   2016-01-02    478
#   NaN            -2
#   Length: 479, dtype: int64,
#   'data_type': dtype('O')},
#  {'col': 'day_of_week',
#   'mapping': Wednesday    1
#   Thursday     2
#   Friday       3
#   Saturday     4
#   Monday       5
#   Tuesday      6
#   Sunday       7
#   NaN         -2
#   dtype: int64,
# ...

# %%
# OneHot Encoding in category_encoders
ohe = ce.OneHotEncoder(use_cat_names=True)
ohe.fit_transform(df['day_of_week'])
# Out:
#         day_of_week_Wednesday  day_of_week_Thursday  day_of_week_Friday  \
# 0                           1                     0                   0
# 1                           0                     1                   0
# 2                           0                     0                   1
# 3                           0                     0                   0
# 4                           0                     0                   0
# ...                       ...                   ...                 ...
# 252103                      0                     0                   1
# 252104                      0                     0                   0
# 252105                      0                     0                   0
# 252106                      0                     0                   0
# 252107                      0                     0                   0
#
#         day_of_week_Saturday  day_of_week_Monday  day_of_week_Tuesday  \
# ...

# %%
# ?ce.OneHotEncoder

# %%
df.id.value_counts()
# Out:
# air_5c817ef28f236bdf    477
# air_a083834e7ffe187e    476
# air_36bcf77d3382d36e    476
# air_d97dabf7aae60da5    476
# air_60a7057184ec7ec7    475
#                        ...
# air_1c0b150f9e696a5f     51
# air_a17f0778617c76e2     47
# air_789103bf53b8096b     41
# air_a9a380530c1e121f     40
# air_900d755ebd2f7bbd     20
# Name: id, Length: 829, dtype: int64

# %%
te = ce.TargetEncoder()
# you need to declare X & y for this
X, y = df.drop('visitors', axis=1), df['visitors']
# observe the value for day_of_week
te.fit_transform(X, y)
# Out:
#                id visit_date  calendar_date  day_of_week  holiday      genre  \
# 0       22.782609 2016-01-13      18.433460    19.230121        0  18.723532
# 1       22.782609 2016-01-14      19.229927    18.922702        0  18.723532
# 2       22.782609 2016-01-15      23.506897    23.072737        0  18.723532
# 3       22.782609 2016-01-16      26.780142    26.313688        0  18.723532
# 4       22.782609 2016-01-18      14.486726    17.177009        0  18.723532
# ...           ...        ...            ...          ...      ...        ...
# 252103  44.595745 2017-04-21      25.030612    23.072737        0  22.582953
# 252104  44.595745 2017-04-22      27.448320    26.313688        0  22.582953
# 252105  44.595745 2017-03-26      24.098333    23.873362        0  22.582953
# 252106  44.595745 2017-03-20      24.043400    17.177009        1  22.582953
# 252107  44.595745 2017-04-09      23.018550    23.873362        0  22.582953
#
# ...

# %%
df.groupby('id')['visitors'].mean()
# Out:
# id
# air_00a91d42b08b08d9    26.081897
# air_0164b9927d20bcc3     9.248322
# air_0241aa3964b7f861     9.896465
# air_0328696196e46f18     7.939655
# air_034a3d5b40d5b1b1    14.828685
#                           ...
# air_fea5dc9594450608    14.485401
# air_fee8dcf4d619598e    26.027778
# air_fef9ccb3ba0da2f7     9.620408
# air_ffcc2d5087e1b476    20.242798
# air_fff68b929994bfbd     5.089219
# Name: visitors, Length: 829, dtype: float64

# %%
df.id.value_counts()
# Out:
# air_5c817ef28f236bdf    477
# air_a083834e7ffe187e    476
# air_36bcf77d3382d36e    476
# air_d97dabf7aae60da5    476
# air_60a7057184ec7ec7    475
#                        ...
# air_1c0b150f9e696a5f     51
# air_a17f0778617c76e2     47
# air_789103bf53b8096b     41
# air_a9a380530c1e121f     40
# air_900d755ebd2f7bbd     20
# Name: id, Length: 829, dtype: int64

# %%
# let's save our transformed dataset from target encoding
transformed = te.fit_transform(X, y)
# and look up the value for air_900d755ebd2f7bbd -- the restaurant with the lowest attendance value
transformed.id.value_counts()
# Out:
# 15.288732     568
# 37.754717     477
# 37.754202     476
# 31.777311     476
# 27.325630     476
#              ...
# 115.470588     51
# 44.595745      47
# 55.243902      41
# 44.875000      40
# 82.200000      20
# Name: id, Length: 828, dtype: int64

# %%
# let's set min_samples_leaf to 21 -- which will exclude the last value from these calculations
te = ce.TargetEncoder(min_samples_leaf=20, smoothing=1)
# transform it
transformed2 = te.fit_transform(X, y)
# and look at our values for the last one -- way different
transformed2.id.value_counts()
# Out:
# 15.288732     568
# 37.754717     477
# 27.325630     476
# 37.754202     476
# 31.777311     476
#              ...
# 115.470588     51
# 44.595745      47
# 55.243902      41
# 44.875000      40
# 51.586881      20
# Name: id, Length: 828, dtype: int64
