# %% [markdown]
# ## Intermediate Lab:  Creating A Dataset Using the GitHub API
#
# In this lab you'll create a dataset containing all the meta information about your classmates github repos, using only the csv file with everyone's url.
#
# The process will be done in these 4 general steps:
#
#  - load in the csv file
#  - clean the individual lines of each file to get them ready to use
#  - connect to the GitHub api to obtain information about everyone's repos
#  - re-structure this information to turn it into a dataframe.
#
# It'll be a great way to work through the first step of many data science problems: creating a workable dataset out of unorganized, messy data.  Let's get started!

# %% [markdown]
# ### Step 1:  Load in the csv file with everyone's github repo
#
# **Note:** There are a number of ways to do this, but the easiest way is usually this:
#
#     `with open('file.csv') as f:
#
#         data = f.readlines()`

# %%
file = "/Users/cameronlefevre/Desktop/gitrepos.csv"

with open(file) as f:
    data = f.readlines()

# %% [markdown]
# What you should have now is a list, and each item is a string that contains the comma separated values of each cell in the row of that csv file.
#
# It should generically look like this:
#
#     `['Name,Repo\n',
#       'Person 1,https://github.com/username1\n',
#       'Person 2,https://github.com/username2\n',
#        ......
#        ]`
#
# Double check this is the case.

# %%
data
# Out:
# ['Name,Github URL\n',
#  'Chloé,https://github.com/chloemd\n',
#  ',\n',
#  'Gary,https://github.com/Gmarin10\n',
#  'Cameron ,https://github.com/clefevre01\n',
#  'Oore,https://github.com/ladipoore\n',
#  'Jaryd Thornton,https://github.com/jcolethornton\n',
#  'Peter,https://github.com/Lothdyn/my-1019-repo\n',
#  'Alvaro ,https://github.com/alvarog01/mydat1019\n',
#  ',\n',
#  'Amanda Chernishkin,https://github.com/amandachernishkin\n',
#  'John Mayer,https://github.com/mayerjp01\n',
#  'Nidhi Mahambre,https://github.com/nidhim03']

# %% [markdown]
# The only thing we need out of each item is the persons username, that part contained in the string at: `https://github.com/username_here`.  Everything else is junk.
#
# We'll need to go through a few steps to get our info down to a usable format.

# %% [markdown]
# ### Step 2: Remove the `\n` from each item in the list, as well as the item that contains the header info.
#
# When you're done you should have a list that looks like this:
#
#       `[
#       'Person 1,https://github.com/username1',
#       'Person 2,https://github.com/username2',
#        ......
#        ]`
#
# **hint:** The `replace()` method for strings is probably one of the more useful options that you have.  If you want to replace something with nothing, you can simply specify `""` for that part.

# %%
# your code here
users = []

for item in data:
    if "https://github.com/" in item:
        users.append(item.split(",")[1].replace("https://github.com/","").split("/")[0].rstrip())

print(users)
# Out:
# Name,Github URL
#
# Chloé,https://github.com/chloemd
#
# ,
#
# Gary,https://github.com/Gmarin10
#
# Cameron ,https://github.com/clefevre01
#
# Oore,https://github.com/ladipoore
#
# Jaryd Thornton,https://github.com/jcolethornton
#
# Peter,https://github.com/Lothdyn/my-1019-repo
#
# Alvaro ,https://github.com/alvarog01/mydat1019
#
# ,
#
# Amanda Chernishkin,https://github.com/amandachernishkin
#
# John Mayer,https://github.com/mayerjp01
#
# Nidhi Mahambre,https://github.com/nidhim03

# %% [markdown]
# ### Step 3:  Separate the username in each string from everything else
#
# When you're done you should have a new list that looks like this:
#
#     `[
#        'username1',
#        'username2',
#        ...
#      ]`

# %% [markdown]
# **hint:** `split()` is a helpful method for this.  Since the parts of the string are separated by a `/` you could use that to split the string.

# %%
# your code here

# %% [markdown]
# ### Step 4: Obtain the repo data for every single github username
#
# The repository info for every single public account is available via the following url: `https://api.github.com/users/:the_username/repos`
#
# So basically, `requests.get('https://api.github.com/users/:the_username/repos').json()` will return a list filled with every single repo that user has.
#
# When you're done, you should have a *list of lists*, with each list containing each users individual repos.  It'll look like this:
#
# `[[{user1, repo1}, {user1, repo2}], [{user2, repo1}], [{user3, repo1}, {user3, repo2}, {user3, rep3}], .....]`
#
# **Warning:** We're using the free, unauthenticated version of the API here.  That means we can only make 60 API calls per hour before getting throttled.  If we've used up our bandwidth the response you'll get is a dictionary telling you we've exceeded our rate limit or something similar.
#
# If that's the case, try using your phone (or your neighbors) as a hotspot and connect from there to get a new IP address.

# %%
import requests

users = []

for item in data:
    if "https://github.com/" in item:
        users.append(item.split(",")[1].replace("https://github.com/","").split("/")[0].rstrip())

base_url = 'https://api.github.com'

repo_lists = [requests.get(f"{base_url}/users/{user}/repos").json() for user in users]

[requests.get(f"{base_url}/users/{user}/repos").json() for user in users]

print(repo_lists)
# Out:
# chloemd
# [[{'id': 305542140, 'node_id': 'MDEwOlJlcG9zaXRvcnkzMDU1NDIxNDA=', 'name': 'DAT-1019-Chloe', 'full_name': 'chloemd/DAT-1019-Chloe', 'private': False, 'owner': {'login': 'chloemd', 'id': 73141231, 'node_id': 'MDQ6VXNlcjczMTQxMjMx', 'avatar_url': 'https://avatars1.githubusercontent.com/u/73141231?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/chloemd', 'html_url': 'https://github.com/chloemd', 'followers_url': 'https://api.github.com/users/chloemd/followers', 'following_url': 'https://api.github.com/users/chloemd/following{/other_user}', 'gists_url': 'https://api.github.com/users/chloemd/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/chloemd/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/chloemd/subscriptions', 'organizations_url': 'https://api.github.com/users/chloemd/orgs', 'repos_url': 'https://api.github.com/users/chloemd/repos', 'events_url': 'https://api.github.com/users/chloemd/events{/privacy}', 'received_events_url': 'https://api.github.com/users/chloemd/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/chloemd/DAT-1019-Chloe', 'description': 'My DAT 10/19 repo', 'fork': False, 'url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe', 'forks_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/forks', 'keys_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/teams', 'hooks_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/hooks', 'issue_events_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues/events{/number}', 'events_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/events', 'assignees_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/assignees{/user}', 'branches_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/branches{/branch}', 'tags_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/tags', 'blobs_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/languages', 'stargazers_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/stargazers', 'contributors_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/contributors', 'subscribers_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/subscribers', 'subscription_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/subscription', 'commits_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/contents/{+path}', 'compare_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/merges', 'archive_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/downloads', 'issues_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues{/number}', 'pulls_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/milestones{/nu ...

# %% [markdown]
# ### Step 5: Create a 'flat' list that contains every unique repo for every single user
#
# When you're done you should have a list that looks like this: `[{user1 repo1}, {user1 repo2}, ....{user n, repo m}]`
#
# Ie, instead of having a list filled with other lists with dictionaries inside of them, make it a list with just dictionaries on the inside.
#
# Ie, no nested levels like you had before.
#
# So, go from this:
#
# `[[{user1, repo1}, {user1, repo2}, {user1, repo3}], [{user2, repo1}, {user2, repo2}]]`
#
# To this:
#
# `[{user1, repo1}, {user1, repo2}, {user1, repo3}, {user2, repo1}, {user2, repo2}]`
#
# If you have questions about what this entails, then please contact me ASAP.

# %%
# your code here
repos = [repo for user in repo_lists for repo in user]

repos[0]
# Out:
# {'id': 305542140,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzMDU1NDIxNDA=',
#  'name': 'DAT-1019-Chloe',
#  'full_name': 'chloemd/DAT-1019-Chloe',
#  'private': False,
#  'owner': {'login': 'chloemd',
#   'id': 73141231,
#   'node_id': 'MDQ6VXNlcjczMTQxMjMx',
#   'avatar_url': 'https://avatars1.githubusercontent.com/u/73141231?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/chloemd',
#   'html_url': 'https://github.com/chloemd',
#   'followers_url': 'https://api.github.com/users/chloemd/followers',
#   'following_url': 'https://api.github.com/users/chloemd/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/chloemd/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/chloemd/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/chloemd/subscriptions',
#   'organizations_url': 'https://api.github.com/users/chloemd/orgs',
#   'repos_url': 'https://api.github.com/users/chloemd/repos',
#   'events_url': 'https://api.github.com/users/chloemd/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/chloemd/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/chloemd/DAT-1019-Chloe',
#  'description': 'My DAT 10/19 repo',
#  'fork': False,
#  'url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe',
#  'forks_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/forks',
#  'keys_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/teams',
#  'hooks_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/hooks',
#  'issue_events_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/events',
#  'assignees_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/tags',
#  'blobs_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/languages',
#  'stargazers_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/stargazers',
#  'contributors_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/contributors',
#  'subscribers_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/subscribers',
#  'subscription_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/subscription',
#  'commits_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/merges',
#  'archive_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/downloads',
#  'issues_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/deployments',
#  'created_at': '2020-10-20T00:00:09Z',
#  'updated_at': '2020-10-26T22:03:37Z',
#  'pushed_at': '2020-10-26T22:03:35Z',
#  'git_url': 'git://github.com/chloemd/DAT-1019-Chloe.git',
#  'ssh_url': 'git@github.com:chloemd/DAT-1019-Chloe.git',
#  'clone_url': 'https://github.com/chloemd/DAT-1019-Chloe.git',
#  'svn_url': 'https://github.com/chloemd/DAT-1019-Chloe',
#  'homepage': None,
#  'size': 1456,
#  'stargazers_count': 1,
#  'watchers_count': 1,
#  'language': 'Jupyter Notebook',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'forks_count': 0,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 0,
#  'license': None,
#  'forks': 0,
#  'open_issues': 0,
#  'watchers': 1,
#  'default_branch': 'main'}

# %% [markdown]
# ### Step 6:  Get information about the name, owner, url, and date of every single repo.
#
# We are **almost** there to getting a true dataset out of our API calls.  The problem we have now is that our dictionary is nested.  Ie, some of the values are other dictionaries or lists.
#
# To make these values accessible to pandas we need to have them all on an equal footing.
#
# In the dictionary for each repo there are keys called `name`, `login`, `html_url`, and `created_at`.  These are going to populate the values for our different columns.
#
# If you look, you'll see that the `login` key is nested inside another dictionary.
#
# What we want to do is have the values for each of these keys inside their own separate lists, so their values can be re-used more easily.
#
# So what you need to do is use for loops to create a list that contains all the individual values for each of these dictionary keys.
#
# You should results that look like this:
#
# `names  = [list filled with all of the values of the name key]`
#
# `logins = [list filled with all of the values of the login key]`
#
# `urls   = [list filled with all of the values of the html_url key]`
#
# `dates  = [list filled with all of the values of the created_at key]`
#
# **hint:** Notice that the `login` key is nested inside a dictionary that's the value to the `owner` key at the outer level.

# %%
repo_names = [repo['name'] for repo in repos]
repo_logins = [repo['owner']['login'] for repo in repos]
repo_urls = [repo['url'] for repo in repos]
repo_dates = [repo['created_at'] for repo in repos]

# %% [markdown]
# ### Step 7:  Create a dictionary with the data created from step 7
#
# Your final output should look like this:
#
#     `{
#        'Owner': [list with the `login` values for each user],
#        'Name' : [list with the `name` values for each user],
#        'URL'  : [list with the `html_url` values for each user],
#        'Date' : [list with the `created_at` values for each user]
#      }`

# %%
repo_dict = {
    'Owner': repo_logins,
    'Name': repo_names,
    'URL': repo_urls,
    'Date': repo_dates
}

# %% [markdown]
# ### Step 8:  Pass your dictionary into the `pd.dataframe()` method to get your final dataset
#
# Use the `df.head()` method to confirm that you have something that's formatted appropriately.

# %%
import pandas as pd

df = pd.DataFrame(repo_dict)

df.head()
# Out:
#       Owner            Name  \
# 0   chloemd  DAT-1019-Chloe
# 1  Gmarin10             DP2
# 2  Gmarin10     GA-DAT-1019
# 3  Gmarin10   Project-Basta
# 4  Gmarin10    Wallbreakers
#
#                                                  URL                  Date
# 0  https://api.github.com/repos/chloemd/DAT-1019-...  2020-10-20T00:00:09Z
# 1          https://api.github.com/repos/Gmarin10/DP2  2018-02-01T22:47:29Z
# 2  https://api.github.com/repos/Gmarin10/GA-DAT-1019  2020-10-20T00:00:09Z
# 3  https://api.github.com/repos/Gmarin10/Project-...  2019-06-11T23:08:20Z
# 4  https://api.github.com/repos/Gmarin10/Wallbrea...  2019-06-24T22:59:34Z

# %%
# Out:
#                 Owner                   Name  \
# 0             chloemd         DAT-1019-Chloe
# 1            Gmarin10                    DP2
# 2            Gmarin10            GA-DAT-1019
# 3            Gmarin10          Project-Basta
# 4            Gmarin10           Wallbreakers
# 5          clefevre01              Test-Repo
# 6           ladipoore               DAT-1019
# 7           ladipoore            EdgarSearch
# 8           ladipoore                  Euler
# 9           ladipoore            PythonClass
# 10          ladipoore          PythonProject
# 11          ladipoore                STA9794
# 12      jcolethornton              DAT-10-19
# 13      jcolethornton     Python-useful_code
# 14            Lothdyn  find-close-meteorites
# 15            Lothdyn           my-1019-repo
# 16          alvarog01              mydat1019
# 17  amandachernishkin                My_repo
# 18          mayerjp01           Data-Science
# 19           nidhim03           GA_DAT-10-19
#
#                                                   URL                  Date
# 0           https://github.com/chloemd/DAT-1019-Chloe  2020-10-20T00:00:09Z
# 1                     https://github.com/Gmarin10/DP2  2018-02-01T22:47:29Z
# 2             https://github.com/Gmarin10/GA-DAT-1019  2020-10-20T00:00:09Z
# 3           https://github.com/Gmarin10/Project-Basta  2019-06-11T23:08:20Z
# 4            https://github.com/Gmarin10/Wallbreakers  2019-06-24T22:59:34Z
# 5             https://github.com/clefevre01/Test-Repo  2020-10-20T00:00:08Z
# 6               https://github.com/ladipoore/DAT-1019  2020-10-20T00:00:13Z
# 7            https://github.com/ladipoore/EdgarSearch  2017-07-27T01:36:00Z
# 8                  https://github.com/ladipoore/Euler  2017-02-10T04:59:29Z
# 9            https://github.com/ladipoore/PythonClass  2017-02-14T00:54:42Z
# 10         https://github.com/ladipoore/PythonProject  2017-04-27T19:35:33Z
# 11               https://github.com/ladipoore/STA9794  2017-02-09T16:52:44Z
# 12         https://github.com/jcolethornton/DAT-10-19  2020-10-20T00:00:07Z
# 13  https://github.com/jcolethornton/Python-useful...  2020-10-16T05:15:33Z
# 14   https://github.com/Lothdyn/find-close-meteorites  2020-04-13T01:42:43Z
# 15            https://github.com/Lothdyn/my-1019-repo  2020-10-20T00:00:09Z
# 16             https://github.com/alvarog01/mydat1019  2020-10-20T00:00:11Z
# 17       https://github.com/amandachernishkin/My_repo  2020-10-20T00:00:08Z
# 18          https://github.com/mayerjp01/Data-Science  2020-10-20T00:00:07Z
# 19           https://github.com/nidhim03/GA_DAT-10-19  2020-10-20T00:10:22Z
